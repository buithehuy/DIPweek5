# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = '1.jpg'
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Image')
plt.show()

# %%
x, y, w, h = 1530, 1600, 110, 130 

template_tennisball = image[y:y+h, x:x+w]

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(template_tennisball, cv2.COLOR_BGR2RGB))
plt.title('Original Template')
plt.axis('off')

gray_template_tennisball = cv2.cvtColor(template_tennisball, cv2.COLOR_BGR2GRAY)
_, thresh_template = cv2.threshold(gray_template_tennisball, 120, 255, cv2.THRESH_BINARY_INV)

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(thresh_template, cv2.COLOR_BGR2RGB))
plt.title('Binary Template')
plt.axis('off')
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
_, binary_image = cv2.threshold(gray_image, 120, 255, cv2.THRESH_BINARY_INV)
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(binary_image, cv2.COLOR_BGR2RGB))
plt.title('Binary Image')
plt.axis('off')
plt.show()

# %%
image = cv2.imread(image_path)
for scale in np.linspace(0.5, 1.0, 100): 
    resized_template = cv2.resize(thresh_template, (0, 0), fx=scale, fy=scale)
    
    result = cv2.matchTemplate(binary_image, resized_template, cv2.TM_CCOEFF_NORMED)


    threshold = 0.6
    loc = np.where(result >= threshold)

    for pt in zip(*loc[::-1]):
        cv2.rectangle(image, pt, (pt[0] + int(w * scale), pt[1] + int(h * scale)), (255, 0 , 0), 10)


image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.title(f'Matching areas with threshold {threshold}')
plt.axis('off')
plt.show()

# %%
x, y, w, h = 1770, 1600, 110, 130 

template_strawberry = image[y:y+h, x:x+w]

gray_template_strawberry = cv2.cvtColor(template_strawberry, cv2.COLOR_BGR2GRAY)
_, thresh_template_strawberry = cv2.threshold(gray_template_strawberry, 120, 255, cv2.THRESH_BINARY_INV)

plt.imshow(cv2.cvtColor(thresh_template_strawberry, cv2.COLOR_BGR2RGB))
plt.title('Cropped Template')
plt.axis('off')
plt.show()

# %%
image = cv2.imread(image_path)
for scale in np.linspace(0.5, 1.0, 100): 
    resized_template_strawberry = cv2.resize(thresh_template_strawberry, (0, 0), fx=scale, fy=scale)
    
    result = cv2.matchTemplate(binary_image, resized_template_strawberry, cv2.TM_CCOEFF_NORMED)


    threshold = 0.6
    loc = np.where(result >= threshold)

    for pt in zip(*loc[::-1]):
        cv2.rectangle(image, pt, (pt[0] + int(w * scale), pt[1] + int(h * scale)), (255, 0 , 0), 10)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.title(f'Matching areas with threshold {threshold}')
plt.axis('off')
plt.show()

# %% [markdown]
# **Other Approach**

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
edges_image = cv2.Canny(gray_image, 100, 200)      
plt.imshow(cv2.cvtColor(edges_image, cv2.COLOR_BGR2RGB))
plt.title('Edge Image')
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(template_tennisball, cv2.COLOR_BGR2RGB))
plt.title('Original Template')
plt.axis('off')

gray_template_tennisball = cv2.cvtColor(template_tennisball, cv2.COLOR_BGR2GRAY)
edges_template_tennisball = cv2.Canny(gray_template_tennisball, 100, 200) 

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(edges_template_tennisball, cv2.COLOR_BGR2RGB))
plt.title('Edge Template')
plt.axis('off')
plt.show()

# %%
image = cv2.imread(image_path)
for scale in np.linspace(0.4, 1.0, 100): 
    resized_template_tennisball = cv2.resize(edges_template_tennisball, (0, 0), fx=scale, fy=scale)
    
    result = cv2.matchTemplate(edges_image, resized_template_tennisball, cv2.TM_CCOEFF_NORMED)


    threshold = 0.4
    loc = np.where(result >= threshold)

    for pt in zip(*loc[::-1]):
        cv2.rectangle(image, pt, (pt[0] + int(w * scale), pt[1] + int(h * scale)), (255, 0 , 0), 10)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.title(f'Matching areas with threshold {threshold}')
plt.axis('off')
plt.show()

# %%
image_path2 = '2.jpg'
image2 = cv2.imread(image_path2)
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.title('Image')
plt.show()

# %%
gray_image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
edges_image2 = cv2.Canny(gray_image2, 100, 200)      
plt.imshow(cv2.cvtColor(edges_image2, cv2.COLOR_BGR2RGB))
plt.title('Edge Image')
plt.show()

# %%
x, y, w, h = 1915, 2080, 200, 230 

template2 = image2[y:y+h, x:x+w]

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(template2, cv2.COLOR_BGR2RGB))
plt.title('Original Template')
plt.axis('off')

gray_template2 = cv2.cvtColor(template2, cv2.COLOR_BGR2GRAY)
edges_template2 = cv2.Canny(gray_template2, 100, 200) 

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(edges_template2, cv2.COLOR_BGR2RGB))
plt.title('Edge Template')
plt.axis('off')
plt.show()

# %%
image2 = cv2.imread(image_path2)
for scale in np.linspace(0.4, 1.0, 100): 
    resized_template2= cv2.resize(edges_template2, (0, 0), fx=scale, fy=scale)
    
    result = cv2.matchTemplate(edges_image2, resized_template2, cv2.TM_CCOEFF_NORMED)


    threshold = 0.4
    loc = np.where(result >= threshold)

    for pt in zip(*loc[::-1]):
        cv2.rectangle(image2, pt, (pt[0] + int(w * scale), pt[1] + int(h * scale)), (255, 0 , 0), 10)

image_rgb2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb2)
plt.title(f'Matching areas with threshold {threshold}')
plt.axis('off')
plt.show()
